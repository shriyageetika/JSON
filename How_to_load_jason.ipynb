# %% [markdown]
# <a href="https://colab.research.google.com/github/shriyageetika/JSON/blob/main/How_to_load_jason.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**How to load a Jason file using Pandas**

# %% [markdown]
# These files are widely used for data exchange between web services, and they have become a popular format for storing data. If you work with Jupyter Notebook, you can easily load JSON files using the pandas library.

# %% [markdown]
# Pandas is a powerful library for data manipulation and analysis. It provides a convenient way to work with tabular data, and it is widely used in the data science community. When it comes to loading JSON files, pandas offers several benefits:
#
#   *Pandas can handle large JSON files with ease.
#
#   *Pandas can convert JSON data into a tabular format, which makes it easier to work with.
#
#   *Pandas can handle missing data in JSON files.

# %% [markdown]
# To load a JSON file in Jupyter Notebook using pandas, follow these steps:

# %%
{
    "data": [
      {"id": 1, "name": "John", "age": 25, "city": "New York"},
      {"id": 2, "name": "Alice", "age": 30, "city": "San Francisco"},
      {"id": 3, "name": "Bob", "age": 25, "city": "Los Angeles"},
      {"id": 4, "name": "Eve", "age": 35, "city": "Chicago"}
    ]
  }
# Out:
# {'data': [{'id': 1, 'name': 'John', 'age': 25, 'city': 'New York'},
#   {'id': 2, 'name': 'Alice', 'age': 30, 'city': 'San Francisco'},
#   {'id': 3, 'name': 'Bob', 'age': 25, 'city': 'Los Angeles'},
#   {'id': 4, 'name': 'Eve', 'age': 35, 'city': 'Chicago'}]}

# %%
df.head()
# Out:
#                                                 data
# 0  {'id': 1, 'name': 'John', 'age': 25, 'city': '...
# 1  {'id': 2, 'name': 'Alice', 'age': 30, 'city': ...
# 2  {'id': 3, 'name': 'Bob', 'age': 25, 'city': 'L...
# 3  {'id': 4, 'name': 'Eve', 'age': 35, 'city': 'C...

# %%
import pandas as pd

# %%
import json as json_data

# %% [markdown]
# #**Explore the Data**
#
# Now that we have loaded the JSON file into a pandas DataFrame object, we can explore the data using pandas functions. For example, we can use the df.head() function to view the first few rows of the DataFrame:
#
# If our JSON file contains nested structures, such as dictionaries within columns, we may want to use the json_normalize function to flatten the data. This is particularly useful for handling nested JSON structures.

# %%
df.head()
# Out:
#                                                 data
# 0  {'id': 1, 'name': 'John', 'age': 25, 'city': '...
# 1  {'id': 2, 'name': 'Alice', 'age': 30, 'city': ...
# 2  {'id': 3, 'name': 'Bob', 'age': 25, 'city': 'L...
# 3  {'id': 4, 'name': 'Eve', 'age': 35, 'city': 'C...

# %%
df_normalized = pd.json_normalize(df['data'])

df_normalized.head()
# Out:
#    id   name  age           city
# 0   1   John   25       New York
# 1   2  Alice   30  San Francisco
# 2   3    Bob   25    Los Angeles
# 3   4    Eve   35        Chicago

# %% [markdown]
# #**Manipulate the Data**
# Once we have loaded the JSON file into a pandas DataFrame object, we can manipulate the data using pandas functions. For example, we can use the df.groupby() function to group the data by a specific column:

# %%
grouped = df_normalized.groupby('age')
for age, group in grouped:
    print(f"Age: {age}")
    print(group)
    print()
# Out:
# Age: 25
#    id  name  age         city
# 0   1  John   25     New York
# 2   3   Bob   25  Los Angeles
#
# Age: 30
#    id   name  age           city
# 1   2  Alice   30  San Francisco
#
# Age: 35
#    id name  age     city
# 3   4  Eve   35  Chicago

# %% [markdown]
# #**Visualize the Data**
#
# Finally, we can visualize the data using pandas functions or other visualization libraries like Matplotlib. For example, you can use the df.plot() function to create a simple plot.

# %%
df_normalized.plot()
# Out:
# <Axes: >

# %% [markdown]
# #**Conclusion**
#
# Pandas is a powerful library for data manipulation and analysis, and it provides a convenient way to work with JSON files. By following the steps outlined in this post, you can easily load and manipulate JSON data in Jupyter Notebook using pandas.
